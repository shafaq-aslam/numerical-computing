# %% [markdown]
#  # 1. Numbers And Types

# %%
import numpy as np
vector_row = np.array([[1, -5, 3, 2, 4]])
vector_col = np.array([[1], [2], [3], [4]])

print(vector_row.shape)
print(vector_col.shape)
# Out:
# (1, 5)
# (4, 1)

# %%
print(vector_row)
print(vector_col)
# Out:
# [[ 1 -5  3  2  4]]
# [[1]
#  [2]
#  [3]
#  [4]]

# %%
import sys
sys.float_info
# Out:
# sys.float_info(max=1.7976931348623157e+308, max_exp=1024, max_10_exp=308, min=2.2250738585072014e-308, min_exp=-1021, min_10_exp=-307, dig=15, mant_dig=53, epsilon=2.220446049250313e-16, radix=2, rounds=1)

# %%
np.spacing(100_000_000) # Spacing tells us how far 'nect largest/smallest' number is
# Out:
# np.float64(1.4901161193847656e-08)

# %%
np.spacing(100.2) # notice smaller spacing at this point
# Out:
# np.float64(1.4210854715202004e-14)

# %%
print(np.spacing(1e4))
print(np.spacing(1e-4))
# Out:
# 1.8189894035458565e-12
# 1.3552527156068805e-20

# %% [markdown]
# # 2. Floating Point Numbers
