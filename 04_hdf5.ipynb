# %% [markdown]
# # 1. Issues Of Scale

# %% [markdown]
# ## 1.1. HDF5 - The Why & How

# %% [markdown]
# Since we're on the topic of limits, let's go ahead and take a look at a case study that is very often handy when doing data analysis, machine learning and all related areas.
#
# The issue we consider here is that of handling very large datasets that do not fit in memory.
#
# For instance, you may have a dataset that is 85GB large but you only have 32GB main memory in your system. You can let your OS handle the memory but that is going to be too inefficient as the OS has no "understanding" of the data. Instead, we use a library that can do the loading of data in an intelligent manner. We'll see HDF5 here for that. The python interface to this is called h5py.
#
# Let's simulate creation of a large dataset

# %%
# !pip install h5py
# Out:
# Requirement already satisfied: h5py in c:\users\hp\miniconda3\lib\site-packages (3.16.0)
# Requirement already satisfied: numpy>=1.21.2 in c:\users\hp\miniconda3\lib\site-packages (from h5py) (2.5.1)

# %%
# !pip install pandas
# Out:
# Requirement already satisfied: pandas in c:\users\hp\miniconda3\lib\site-packages (3.0.5)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\hp\miniconda3\lib\site-packages (from pandas) (2.5.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\hp\miniconda3\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: tzdata in c:\users\hp\miniconda3\lib\site-packages (from pandas) (2026.3)
# Requirement already satisfied: six>=1.5 in c:\users\hp\miniconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)

# %%
conda install pytables
# Out:
# Jupyter detected...
# 3 channel Terms of Service accepted
# Channels:
#  - defaults
# Platform: win-64
# Collecting package metadata (repodata.json): done
# Solving environment: done
#
# # All requested packages already installed.
#
#
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np
import pandas as pd

# %%
#this will be our HDF5 file --- for future practice
filename = 'data/test.h5'

# %%
df = pd.DataFrame(np.arange(20).reshape((5, 4)), columns=['A', 'B', 'C', 'D'])
print(df)
# Out:
#     A   B   C   D
# 0   0   1   2   3
# 1   4   5   6   7
# 2   8   9  10  11
# 3  12  13  14  15
# 4  16  17  18  19

# %%
# Save to HDF5
df.to_hdf(filename, key='data', mode='w', format='table')

del df    # allow df to be garbage collected

# %%
# Append more data
df2 = pd.DataFrame(np.arange(20).reshape((5,4)) * 10, 
                   columns=['A', 'B', 'C', 'D'])


# This is the important bit! Remove `append` to see the difference 
df2.to_hdf(filename, key='data', append=True)

del df2

# %%
print(pd.read_hdf(filename, key='data'))
# Out:
#      A    B    C    D
# 0    0    1    2    3
# 1    4    5    6    7
# 2    8    9   10   11
# 3   12   13   14   15
# 4   16   17   18   19
# 0    0   10   20   30
# 1   40   50   60   70
# 2   80   90  100  110
# 3  120  130  140  150
# 4  160  170  180  190
