# %% [markdown]
# # 1. Numpy Intro

# %%
# %matplotlib inline
# %run mplimp.py

# %%
# !pip install numpy

# %%
import numpy as np

# %%
np.random.seed(1337)

# %% [markdown]
# ## 1.1 Basics of Matrices

# %%
x = np.array([1, 4, 3])
x
# Out:
# array([1, 4, 3])
